# %%
import requests
import csv
import time

# Define the URL for the streaming endpoint
url = 'https://www.floods.it/api/v1/monitoring/38561.csv'

# Open a CSV file to write the data
with open('sensor_data.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    # Write the header row
    writer.writerow(['IdSensore', 'Data/Ora', 'Valore', 'Validato','OraSolare'])

    # Connect to the URL and stream data
    response = requests.get(url, stream=True)

    if response.status_code == 200:
        print("Connected to the stream. Writing data to CSV...")
        for line in response.iter_lines():
            if line:
                # Decode the byte stream and process the data
                data = line.decode('utf-8')
                # Assume data is in JSON format, parse it accordingly
                try:
                    import json
                    json_data = json.loads(data)
                    # Extract relevant fields (this will depend on your data format)
                    IdSensor = json_data.get('IdSensore')
                    timestamp = json_data.get('Data/Ora')
                    value = json_data.get('Valore')
                    valstate = json_data.get('Validato')
                    solhour = json_data.get('OraSolare')
                    # Write the data to the CSV file
                    writer.writerow([timestamp, IdSensor, value])
                    print(f"Wrote data: {timestamp}, {IdSensor}, {value}, {valstate}, {solhour}")
                except json.JSONDecodeError:
                    print("Failed to decode JSON:", data)
    else:
        print(f"Failed to connect to {url}. Status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 15
#      12 writer.writerow(['IdSensore', 'Data/Ora', 'Valore', 'Validato','OraSolare'])
#      14 # Connect to the URL and stream data
# ---> 15 response = requests.get(url, stream=True)
#      17 if response.status_code == 200:
#      18     print("Connected to the stream. Writing data to CSV...")
#
# File ~/.cache/pypoetry/virtualenvs/data-science-KLwnPlAe-py3.10/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/data-science-KLwnPlAe-py3.10/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/data-science-KLwnPlAe-py3.10/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.cache/pypoetry/virtualenvs/data-science-KLwnPlAe-py3.10/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.cache/pypoetry/virtualenvs/data-science-KLwnPlAe-py3.10/lib/python3.10/site-packages/requests/adapters.py:564, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     561     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     563 try:
# --> 564     resp = conn.urlopen(
#     565         method=request.method,
#     566         url=url,
#     567         body=request.body,
#     568         headers=request.headers,
#     569         redirect=False,
#     570         assert_same_host=False,
#     571         preload_content=False,
#     572         decode_content=False,
#     573         retries=self.max_retries,
#     574         timeout=timeout,
#     575         chunked=chunked,
#     576     )
#     578 except (ProtocolError, OSError) as err:
#     579     raise ConnectionError(err, request=request)
#
# File ~/.cache/pypoetry/virtualenvs/data-science-KLwnPlAe-py3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/.cache/pypoetry/virtualenvs/data-science-KLwnPlAe-py3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:496, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#     495 try:
# --> 496     conn.request(
#     497         method,
#     498         url,
#     499         body=body,
#     500         headers=headers,
#     501         chunked=chunked,
#     502         preload_content=preload_content,
#     503         decode_content=decode_content,
#     504         enforce_content_length=enforce_content_length,
#     505     )
#     507 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     508 # legitimately able to close the connection after sending a valid response.
#     509 # With this behaviour, the received response is still readable.
#     510 except BrokenPipeError:
#
# File ~/.cache/pypoetry/virtualenvs/data-science-KLwnPlAe-py3.10/lib/python3.10/site-packages/urllib3/connection.py:400, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     398 for header, value in headers.items():
#     399     self.putheader(header, value)
# --> 400 self.endheaders()
#     402 # If we're given a body we start sending that in chunks.
#     403 if chunks is not None:
#
# File /usr/lib/python3.10/http/client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1276 else:
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.10/http/client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1036 msg = b"\r\n".join(self._buffer)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#    1043     if hasattr(message_body, 'read'):
#    1044         # Let file-like take precedence over byte-like.  This
#    1045         # is needed to allow the current position of mmap'ed
#    1046         # files to be taken into account.
#
# File /usr/lib/python3.10/http/client.py:976, in HTTPConnection.send(self, data)
#     974 if self.sock is None:
#     975     if self.auto_open:
# --> 976         self.connect()
#     977     else:
#     978         raise NotConnected()
#
# File ~/.cache/pypoetry/virtualenvs/data-science-KLwnPlAe-py3.10/lib/python3.10/site-packages/urllib3/connection.py:238, in HTTPConnection.connect(self)
#     237 def connect(self) -> None:
# --> 238     self.sock = self._new_conn()
#     239     if self._tunnel_host:
#     240         # If we're tunneling it means we're connected to our proxy.
#     241         self._has_connected_to_proxy = True
#
# File ~/.cache/pypoetry/virtualenvs/data-science-KLwnPlAe-py3.10/lib/python3.10/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     193 """Establish a socket connection and set nodelay settings on it.
#     194
#     195 :return: New socket connection.
#     196 """
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#     205     raise NameResolutionError(self.host, self, e) from e
#
# File ~/.cache/pypoetry/virtualenvs/data-science-KLwnPlAe-py3.10/lib/python3.10/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %%
import requests
import csv
import time

# Define the URL of the endpoint
url = "https://www.floods.it/api/v1/monitoring/38561.csv"

# Define the CSV file where data will be stored
output_csv_file = "iot_sensor_data.csv"

def stream_to_csv(url, output_csv_file):
    # Open the CSV file in append mode
    with open(output_csv_file, mode='a', newline='') as file:
        writer = csv.writer(file)
        
        # Connect to the URL
        response = requests.get(url, stream=True)
        
        # Check if the connection was successful
        if response.status_code == 200:
            print("Connection established. Streaming data...")
            try:
                for line in response.iter_lines():
                    if line:
                        # Decode the line and split by comma
                        decoded_line = line.decode('utf-8')
                        data = decoded_line.split(',')
                        
                        # Write the data to the CSV file
                        writer.writerow(data)
                        print(f"Data written to CSV: {data}")
            except KeyboardInterrupt:
                print("Stream interrupted by user.")
            except Exception as e:
                print(f"An error occurred: {e}")
            finally:
                print("Closing the connection.")
        else:
            print(f"Failed to connect to {url}. Status code: {response.status_code}")

if __name__ == "__main__":
    while True:
        try:
            stream_to_csv(url, output_csv_file)
        except Exception as e:
            print(f"An error occurred: {e}")
        time.sleep(5)  # Wait for a few seconds before attempting to reconnect
# Out:
# Connection established. Streaming data...
# Data written to CSV: ['time_format', '%Y-%m-%d %H:%M:%S']
# Data written to CSV: ['tz', 'UTC+01']
# Data written to CSV: ['api_warnings', '']
# Data written to CSV: ['timestamp', 'value']
# Data written to CSV: ['2024-05-14 00:00:00', '5.822']
# Data written to CSV: ['2024-05-14 00:15:00', '5.633']
# Data written to CSV: ['2024-05-14 00:30:00', '5.784']
# Data written to CSV: ['2024-05-14 00:45:00', '5.746']
# Data written to CSV: ['2024-05-14 01:00:00', '5.596']
# Data written to CSV: ['2024-05-14 01:15:00', '5.708']
# Data written to CSV: ['2024-05-14 01:30:00', '5.596']
# Data written to CSV: ['2024-05-14 01:45:00', '5.746']
# Data written to CSV: ['2024-05-14 02:00:00', '5.708']
# Data written to CSV: ['2024-05-14 02:15:00', '5.746']
# Data written to CSV: ['2024-05-14 02:30:00', '5.671']
# Data written to CSV: ['2024-05-14 02:45:00', '5.784']
# Data written to CSV: ['2024-05-14 03:00:00', '5.746']
# Data written to CSV: ['2024-05-14 03:15:00', '5.558']
# Data written to CSV: ['2024-05-14 03:30:00', '5.708']
# Data written to CSV: ['2024-05-14 03:45:00', '5.671']
# Data written to CSV: ['2024-05-14 04:00:00', '5.633']
# Data written to CSV: ['2024-05-14 04:15:00', '5.822']
# Data written to CSV: ['2024-05-14 04:30:00', '5.708']
# Data written to CSV: ['2024-05-14 04:45:00', '5.746']
# Data written to CSV: ['2024-05-14 05:00:00', '5.708']
# Data written to CSV: ['2024-05-14 05:15:00', '5.633']
# Data written to CSV: ['2024-05-14 05:30:00', '5.558']
# Data written to CSV: ['2024-05-14 05:45:00', '5.596']
# Data written to CSV: ['2024-05-14 06:00:00', '5.596']
# Data written to CSV: ['2024-05-14 06:15:00', '5.596']
# Data written to CSV: ['2024-05-14 06:30:00', '9.772']
# Data written to CSV: ['2024-05-14 06:45:00', '13.079']
# Data written to CSV: ['2024-05-14 07:00:00', '13.405']
# Data written to CSV: ['2024-05-14 07:15:00', '14.18']
# Data written to CSV: ['2024-05-14 07:30:00', '14.18']
# Data written to CSV: ['2024-05-14 07:45:00', '14.236']
# Data written to CSV: ['2024-05-14 08:00:00', '14.012']
# Data written to CSV: ['2024-05-14 08:15:00', '14.292']
# Data written to CSV: ['2024-05-14 08:30:00', '14.348']
# Data written to CSV: ['2024-05-14 08:45:00', '14.18']
# Data written to CSV: ['2024-05-14 09:00:00', '14.461']
# Data written to CSV: ['2024-05-14 09:15:00', '14.068']
# Data written to CSV: ['2024-05-14 09:30:00', '14.292']
# Data written to CSV: ['2024-05-14 09:45:00', '13.956']
# Data written to CSV: ['2024-05-14 10:00:00', '14.236']
# Data written to CSV: ['2024-05-14 10:15:00', '13.845']
# Data written to CSV: ['2024-05-14 10:30:00', '13.956']
# Data written to CSV: ['2024-05-14 10:45:00', '14.236']
# Data written to CSV: ['2024-05-14 11:00:00', '14.068']
# Data written to CSV: ['2024-05-14 11:15:00', '13.901']
# Data written to CSV: ['2024-05-14 11:30:00', '13.68']
# Data written to CSV: ['2024-05-14 11:45:00', '13.845']
# Data written to CSV: ['2024-05-14 12:00:00', '13.956']
# Data written to CSV: ['2024-05-14 12:15:00', '14.012']
# Data written to CSV: ['2024-05-14 12:30:00', '14.012']
# Data written to CSV: ['2024-05-14 12:45:00', '13.845']
# Data written to CSV: ['2024-05-14 13:00:00', '13.956']
# Data written to CSV: ['2024-05-14 13:15:00', '15.667']
# Data written to CSV: ['2024-05-14 13:30:00', '16.078']
# Data written to CSV: ['2024-05-14 13:45:00', '15.784']
# Data written to CSV: ['2024-05-14 14:00:00', '16.315']
# Data written to CSV: ['2024-05-14 14:15:00', '16.078']
# Data written to CSV: ['2024-05-14 14:30:00', '15.784']
# Data written to CSV: ['2024-05-14 14:45:00', '16.078']
# Data written to CSV: ['2024-05-14 15:00:00', '15.784']
# Data written to CSV: ['2024-05-14 15:15:00', '15.667']
# Data written to CSV: ['2024-05-14 15:30:00', '15.376']
# Data written to CSV: ['2024-05-14 15:45:00', '16.434']
# Data written to CSV: ['2024-05-14 16:00:00', '15.667']
# Data written to CSV: ['2024-05-14 16:15:00', '15.609']
# Data written to CSV: ['2024-05-14 16:30:00', '16.197']
# Data written to CSV: ['2024-05-14 16:45:00', '16.197']
# Data written to CSV: ['2024-05-14 17:00:00', '16.256']
# Data written to CSV: ['2024-05-14 17:15:00', '16.614']
# Data written to CSV: ['2024-05-14 17:30:00', '16.375']
# Data written to CSV: ['2024-05-14 17:45:00', '16.434']
# Data written to CSV: ['2024-05-14 18:00:00', '16.375']
# Data written to CSV: ['2024-05-14 18:15:00', '16.197']
# Data written to CSV: ['2024-05-14 18:30:00', '16.256']
# Data written to CSV: ['2024-05-14 18:45:00', '16.197']
# Data written to CSV: ['2024-05-14 19:00:00', '16.614']
# Data written to CSV: ['2024-05-14 19:15:00', '16.375']
# Data written to CSV: ['2024-05-14 19:30:00', '16.434']
# Data written to CSV: ['2024-05-14 19:45:00', '16.315']
# Data written to CSV: ['2024-05-14 20:00:00', '16.197']
# Data written to CSV: ['2024-05-14 20:15:00', '16.256']
# Data written to CSV: ['2024-05-14 20:30:00', '16.315']
# Data written to CSV: ['2024-05-14 20:45:00', '16.256']
# Data written to CSV: ['2024-05-14 21:00:00', '16.256']
# Data written to CSV: ['2024-05-14 21:15:00', '16.078']
# Data written to CSV: ['2024-05-14 21:30:00', '16.734']
# Data written to CSV: ['2024-05-14 21:45:00', '16.315']
# Data written to CSV: ['2024-05-14 22:00:00', '15.901']
# Data written to CSV: ['2024-05-14 22:15:00', '16.197']
# Data written to CSV: ['2024-05-14 22:30:00', '16.078']
# Data written to CSV: ['2024-05-14 22:45:00', '16.315']
# Data written to CSV: ['2024-05-14 23:00:00', '16.434']
# Data written to CSV: ['2024-05-14 23:15:00', '16.554']
# Data written to CSV: ['2024-05-14 23:30:00', '16.256']
# Data written to CSV: ['2024-05-14 23:45:00', '16.315']
# Data written to CSV: ['2024-05-15 00:00:00', '16.078']
# Data written to CSV: ['2024-05-15 00:15:00', '16.078']
# Data written to CSV: ['2024-05-15 00:30:00', '16.315']
# Data written to CSV: ['2024-05-15 00:45:00', '16.375']
# Data written to CSV: ['2024-05-15 01:00:00', '16.197']
# Data written to CSV: ['2024-05-15 01:15:00', '16.434']
# Data written to CSV: ['2024-05-15 01:30:00', '16.197']
# Data written to CSV: ['2024-05-15 01:45:00', '16.019']
# Data written to CSV: ['2024-05-15 02:00:00', '15.492']
# Data written to CSV: ['2024-05-15 02:15:00', '16.434']
# Data written to CSV: ['2024-05-15 02:30:00', '15.901']
# Data written to CSV: ['2024-05-15 02:45:00', '16.315']
# Data written to CSV: ['2024-05-15 03:00:00', '16.078']
# Data written to CSV: ['2024-05-15 03:15:00', '16.434']
# Data written to CSV: ['2024-05-15 03:30:00', '16.256']
# Data written to CSV: ['2024-05-15 03:45:00', '16.256']
# Data written to CSV: ['2024-05-15 04:00:00', '16.078']
# Data written to CSV: ['2024-05-15 04:15:00', '16.197']
# Data written to CSV: ['2024-05-15 04:30:00', '16.375']
# Data written to CSV: ['2024-05-15 04:45:00', '16.078']
# Data written to CSV: ['2024-05-15 05:00:00', '16.197']
# Data written to CSV: ['2024-05-15 05:15:00', '16.078']
# Data written to CSV: ['2024-05-15 05:30:00', '15.667']
# Data written to CSV: ['2024-05-15 05:45:00', '16.078']
# Data written to CSV: ['2024-05-15 06:00:00', '16.315']
# Data written to CSV: ['2024-05-15 06:15:00', '16.019']
# Data written to CSV: ['2024-05-15 06:30:00', '16.375']
# Data written to CSV: ['2024-05-15 06:45:00', '15.784']
# Data written to CSV: ['2024-05-15 07:00:00', '15.901']
# Data written to CSV: ['2024-05-15 07:15:00', '15.96']
# Data written to CSV: ['2024-05-15 07:30:00', '16.434']
# Data written to CSV: ['2024-05-15 07:45:00', '16.078']
# Data written to CSV: ['2024-05-15 08:00:00', '16.434']
# Data written to CSV: ['2024-05-15 08:15:00', '16.256']
# Data written to CSV: ['2024-05-15 08:30:00', '16.614']
# Data written to CSV: ['2024-05-15 08:45:00', '16.915']
# Data written to CSV: ['2024-05-15 09:00:00', '16.915']
# Data written to CSV: ['2024-05-15 09:15:00', '16.734']
# Data written to CSV: ['2024-05-15 09:30:00', '16.975']
# Data written to CSV: ['2024-05-15 09:45:00', '16.854']
# Data written to CSV: ['2024-05-15 10:00:00', '17.34']
# Data written to CSV: ['2024-05-15 10:15:00', '17.401']
# Data written to CSV: ['2024-05-15 10:30:00', '17.523']
# Data written to CSV: ['2024-05-15 10:45:00', '18.329']
# Data written to CSV: ['2024-05-15 11:00:00', '18.454']
# Data written to CSV: ['2024-05-15 11:15:00', '18.454']
# Data written to CSV: ['2024-05-15 11:30:00', '18.204']
# Data written to CSV: ['2024-05-15 11:45:00', '18.705']
# Data written to CSV: ['2024-05-15 12:00:00', '18.769']
# Data written to CSV: ['2024-05-15 12:15:00', '18.517']
# Data written to CSV: ['2024-05-15 12:30:00', '18.454']
# Data written to CSV: ['2024-05-15 12:45:00', '18.141']
# Data written to CSV: ['2024-05-15 13:00:00', '18.017']
# Data written to CSV: ['2024-05-15 13:15:00', '18.329']
# Data written to CSV: ['2024-05-15 13:30:00', '17.955']
# Data written to CSV: ['2024-05-15 13:45:00', '17.401']
# Data written to CSV: ['2024-05-15 14:00:00', '17.893']
# Data written to CSV: ['2024-05-15 14:15:00', '18.329']
# Data written to CSV: ['2024-05-15 14:30:00', '18.517']
# Data written to CSV: ['2024-05-15 14:45:00', '18.017']
# Data written to CSV: ['2024-05-15 15:00:00', '18.769']
# Data written to CSV: ['2024-05-15 15:15:00', '19.662']
# Data written to CSV: ['2024-05-15 15:30:00', '19.405']
# Data written to CSV: ['2024-05-15 15:45:00', '18.705']
# Data written to CSV: ['2024-05-15 16:00:00', '18.391']
# Data written to CSV: ['2024-05-15 16:15:00', '18.517']
# Data written to CSV: ['2024-05-15 16:30:00', '18.204']
# Data written to CSV: ['2024-05-15 16:45:00', '18.769']
# Data written to CSV: ['2024-05-15 17:00:00', '18.329']
# Data written to CSV: ['2024-05-15 17:15:00', '18.017']
# Data written to CSV: ['2024-05-15 17:30:00', '18.266']
# Data written to CSV: ['2024-05-15 17:45:00', '18.329']
# Data written to CSV: ['2024-05-15 18:00:00', '18.895']
# Data written to CSV: ['2024-05-15 18:15:00', '18.517']
# Data written to CSV: ['2024-05-15 18:30:00', '18.958']
# Data written to CSV: ['2024-05-15 18:45:00', '19.213']
# Data written to CSV: ['2024-05-15 19:00:00', '19.149']
# Data written to CSV: ['2024-05-15 19:15:00', '19.727']
# Data written to CSV: ['2024-05-15 19:30:00', '20.771']
# Data written to CSV: ['2024-05-15 19:45:00', '21.302']
# Data written to CSV: ['2024-05-15 20:00:00', '21.704']
# Data written to CSV: ['2024-05-15 20:15:00', '22.313']
# Data written to CSV: ['2024-05-15 20:30:00', '23.832']
# Data written to CSV: ['2024-05-15 20:45:00', '23.623']
# Data written to CSV: ['2024-05-15 21:00:00', '23.136']
# Data written to CSV: ['2024-05-15 21:15:00', '25.108']
# Data written to CSV: ['2024-05-15 21:30:00', '26.265']
# Data written to CSV: ['2024-05-15 21:45:00', '22.861']
# Data written to CSV: ['2024-05-15 22:00:00', '21.906']
# Data written to CSV: ['2024-05-15 22:15:00', '21.771']
# Data written to CSV: ['2024-05-15 22:30:00', '24.113']
# Data written to CSV: ['2024-05-15 22:45:00', '23.483']
# Data written to CSV: ['2024-05-15 23:00:00', '25.395']
# Data written to CSV: ['2024-05-15 23:15:00', '24.608']
# Data written to CSV: ['2024-05-15 23:30:00', '23.832']
# Data written to CSV: ['2024-05-15 23:45:00', '23.973']
# Data written to CSV: ['2024-05-16 00:00:00', '23.692']
# Data written to CSV: ['2024-05-16 00:15:00', '22.723']
# Data written to CSV: ['2024-05-16 00:30:00', '22.313']
# Data written to CSV: ['2024-05-16 00:45:00', '21.771']
# Data written to CSV: ['2024-05-16 01:00:00', '22.518']
# Data written to CSV: ['2024-05-16 01:15:00', '21.771']
# Data written to CSV: ['2024-05-16 01:30:00', '22.109']
# Data written to CSV: ['2024-05-16 01:45:00', '22.245']
# Data written to CSV: ['2024-05-16 02:00:00', '22.381']
# Data written to CSV: ['2024-05-16 02:15:00', '22.177']
# Data written to CSV: ['2024-05-16 02:30:00', '22.109']
# Data written to CSV: ['2024-05-16 02:45:00', '22.313']
# Data written to CSV: ['2024-05-16 03:00:00', '22.177']
# Data written to CSV: ['2024-05-16 03:15:00', '22.449']
# Data written to CSV: ['2024-05-16 03:30:00', '22.655']
# Data written to CSV: ['2024-05-16 03:45:00', '22.861']
# Data written to CSV: ['2024-05-16 04:00:00', '22.861']
# Data written to CSV: ['2024-05-16 04:15:00', '22.177']
# Data written to CSV: ['2024-05-16 04:30:00', '22.177']
# Data written to CSV: ['2024-05-16 04:45:00', '22.586']
# Data written to CSV: ['2024-05-16 05:00:00', '22.449']
# Data written to CSV: ['2024-05-16 05:15:00', '22.245']
# Data written to CSV: ['2024-05-16 05:30:00', '22.586']
# Data written to CSV: ['2024-05-16 05:45:00', '23.136']
# Data written to CSV: ['2024-05-16 06:00:00', '22.861']
# Data written to CSV: ['2024-05-16 06:15:00', '22.381']
# Data written to CSV: ['2024-05-16 06:30:00', '22.998']
# Data written to CSV: ['2024-05-16 06:45:00', '22.655']
# Data written to CSV: ['2024-05-16 07:00:00', '23.067']
# Data written to CSV: ['2024-05-16 07:15:00', '22.655']
# Data written to CSV: ['2024-05-16 07:30:00', '22.655']
# Data written to CSV: ['2024-05-16 07:45:00', '22.861']
# Data written to CSV: ['2024-05-16 08:00:00', '22.998']
# Data written to CSV: ['2024-05-16 08:15:00', '22.586']
# Data written to CSV: ['2024-05-16 08:30:00', '22.655']
# Data written to CSV: ['2024-05-16 08:45:00', '22.861']
# Data written to CSV: ['2024-05-16 09:00:00', '22.861']
# Data written to CSV: ['2024-05-16 09:15:00', '23.344']
# Data written to CSV: ['2024-05-16 09:30:00', '22.792']
# Data written to CSV: ['2024-05-16 09:45:00', '23.067']
# Data written to CSV: ['2024-05-16 10:00:00', '22.998']
# Data written to CSV: ['2024-05-16 10:15:00', '23.206']
# Data written to CSV: ['2024-05-16 10:30:00', '22.861']
# Data written to CSV: ['2024-05-16 10:45:00', '23.206']
# Data written to CSV: ['2024-05-16 11:00:00', '22.723']
# Data written to CSV: ['2024-05-16 11:15:00', '22.792']
# Data written to CSV: ['2024-05-16 11:30:00', '23.136']
# Data written to CSV: ['2024-05-16 11:45:00', '23.344']
# Data written to CSV: ['2024-05-16 12:00:00', '22.998']
# Data written to CSV: ['2024-05-16 12:15:00', '23.344']
# Data written to CSV: ['2024-05-16 12:30:00', '23.344']
# Data written to CSV: ['2024-05-16 12:45:00', '22.998']
# Data written to CSV: ['2024-05-16 13:00:00', '23.623']
# Data written to CSV: ['2024-05-16 13:15:00', '24.254']
# Data written to CSV: ['2024-05-16 13:30:00', '24.822']
# Data written to CSV: ['2024-05-16 13:45:00', '24.537']
# Data written to CSV: ['2024-05-16 14:00:00', '23.692']
# Data written to CSV: ['2024-05-16 14:15:00', '24.113']
# Data written to CSV: ['2024-05-16 14:30:00', '23.483']
# Data written to CSV: ['2024-05-16 14:45:00', '24.679']
# Data written to CSV: ['2024-05-16 15:00:00', '24.608']
# Data written to CSV: ['2024-05-16 15:15:00', '24.043']
# Data written to CSV: ['2024-05-16 15:30:00', '23.483']
# Data written to CSV: ['2024-05-16 15:45:00', '23.973']
# Data written to CSV: ['2024-05-16 16:00:00', '24.679']
# Data written to CSV: ['2024-05-16 16:15:00', '23.762']
# Data written to CSV: ['2024-05-16 16:30:00', '23.973']
# Data written to CSV: ['2024-05-16 16:45:00', '23.414']
# Data written to CSV: ['2024-05-16 17:00:00', '23.832']
# Data written to CSV: ['2024-05-16 17:15:00', '23.762']
# Data written to CSV: ['2024-05-16 17:30:00', '23.483']
# Data written to CSV: ['2024-05-16 17:45:00', '23.275']
# Data written to CSV: ['2024-05-16 18:00:00', '23.973']
# Data written to CSV: ['2024-05-16 18:15:00', '23.692']
# Data written to CSV: ['2024-05-16 18:30:00', '24.254']
# Data written to CSV: ['2024-05-16 18:45:00', '24.325']
# Data written to CSV: ['2024-05-16 19:00:00', '30.57']
# Data written to CSV: ['2024-05-16 19:15:00', '29.104']
# Data written to CSV: ['2024-05-16 19:30:00', '29.18']
# Data written to CSV: ['2024-05-16 19:45:00', '33.515']
# Data written to CSV: ['2024-05-16 20:00:00', '30.492']
# Data written to CSV: ['2024-05-16 20:15:00', '27.744']
# Data written to CSV: ['2024-05-16 20:30:00', '27.818']
# Data written to CSV: ['2024-05-16 20:45:00', '27.893']
# Data written to CSV: ['2024-05-16 21:00:00', '28.799']
# Data written to CSV: ['2024-05-16 21:15:00', '27.818']
# Data written to CSV: ['2024-05-16 21:30:00', '27.744']
# Data written to CSV: ['2024-05-16 21:45:00', '27.0']
# Data written to CSV: ['2024-05-16 22:00:00', '27.371']
# Data written to CSV: ['2024-05-16 22:15:00', '27.445']
# Data written to CSV: ['2024-05-16 22:30:00', '26.779']
# Data written to CSV: ['2024-05-16 22:45:00', '27.074']
# Data written to CSV: ['2024-05-16 23:00:00', '27.968']
# Data written to CSV: ['2024-05-16 23:15:00', '26.192']
# Data written to CSV: ['2024-05-16 23:30:00', '26.926']
# Data written to CSV: ['2024-05-16 23:45:00', '28.269']
# Data written to CSV: ['2024-05-17 00:00:00', '27.669']
# Data written to CSV: ['2024-05-17 00:15:00', '27.0']
# Data written to CSV: ['2024-05-17 00:30:00', '27.669']
# Data written to CSV: ['2024-05-17 00:45:00', '28.345']
# Data written to CSV: ['2024-05-17 01:00:00', '27.818']
# Data written to CSV: ['2024-05-17 01:15:00', '27.669']
# Data written to CSV: ['2024-05-17 01:30:00', '27.371']
# Data written to CSV: ['2024-05-17 01:45:00', '27.296']
# Data written to CSV: ['2024-05-17 02:00:00', '28.194']
# Data written to CSV: ['2024-05-17 02:15:00', '27.669']
# Data written to CSV: ['2024-05-17 02:30:00', '27.818']
# Data written to CSV: ['2024-05-17 02:45:00', '28.119']
# Data written to CSV: ['2024-05-17 03:00:00', '27.669']
# Data written to CSV: ['2024-05-17 03:15:00', '28.043']
# Data written to CSV: ['2024-05-17 03:30:00', '28.194']
# Data written to CSV: ['2024-05-17 03:45:00', '28.496']
# Data written to CSV: ['2024-05-17 04:00:00', '27.669']
# Data written to CSV: ['2024-05-17 04:15:00', '28.194']
# Data written to CSV: ['2024-05-17 04:30:00', '28.269']
# Data written to CSV: ['2024-05-17 04:45:00', '28.647']
# Data written to CSV: ['2024-05-17 05:00:00', '28.647']
# Data written to CSV: ['2024-05-17 05:15:00', '28.345']
# Data written to CSV: ['2024-05-17 05:30:00', '28.194']
# Data written to CSV: ['2024-05-17 05:45:00', '28.496']
# Data written to CSV: ['2024-05-17 06:00:00', '28.951']
# Data written to CSV: ['2024-05-17 06:15:00', '28.951']
# Data written to CSV: ['2024-05-17 06:30:00', '28.799']
# Data written to CSV: ['2024-05-17 06:45:00', '27.818']
# Data written to CSV: ['2024-05-17 07:00:00', '28.119']
# Data written to CSV: ['2024-05-17 07:15:00', '28.647']
# Data written to CSV: ['2024-05-17 07:30:00', '28.496']
# Data written to CSV: ['2024-05-17 07:45:00', '28.496']
# Data written to CSV: ['2024-05-17 08:00:00', '28.647']
# Data written to CSV: ['2024-05-17 08:15:00', '28.496']
# Data written to CSV: ['2024-05-17 08:30:00', '28.799']
# Data written to CSV: ['2024-05-17 08:45:00', '28.799']
# Data written to CSV: ['2024-05-17 09:00:00', '28.496']
# Data written to CSV: ['2024-05-17 09:15:00', '28.875']
# Data written to CSV: ['2024-05-17 09:30:00', '28.799']
# Data written to CSV: ['2024-05-17 09:45:00', '29.41']
# Data written to CSV: ['2024-05-17 10:00:00', '27.594']
# Data written to CSV: ['2024-05-17 10:15:00', '28.496']
# Data written to CSV: ['2024-05-17 10:30:00', '28.496']
# Data written to CSV: ['2024-05-17 10:45:00', '28.647']
# Data written to CSV: ['2024-05-17 11:00:00', '28.647']
# Data written to CSV: ['2024-05-17 11:15:00', '29.333']
# Data written to CSV: ['2024-05-17 11:30:00', '29.487']
# Data written to CSV: ['2024-05-17 11:45:00', '29.18']
# Data written to CSV: ['2024-05-17 12:00:00', '28.647']
# Data written to CSV: ['2024-05-17 12:15:00', '29.18']
# Data written to CSV: ['2024-05-17 12:30:00', '28.951']
# Data written to CSV: ['2024-05-17 12:45:00', '29.18']
# Data written to CSV: ['2024-05-17 13:00:00', '29.104']
# Data written to CSV: ['2024-05-17 13:15:00', '29.718']
# Data written to CSV: ['2024-05-17 13:30:00', '28.496']
# Data written to CSV: ['2024-05-17 13:45:00', '29.333']
# Data written to CSV: ['2024-05-17 14:00:00', '29.18']
# Data written to CSV: ['2024-05-17 14:15:00', '29.41']
# Data written to CSV: ['2024-05-17 14:30:00', '29.333']
# Data written to CSV: ['2024-05-17 14:45:00', '29.333']
# Data written to CSV: ['2024-05-17 15:00:00', '28.799']
# Data written to CSV: ['2024-05-17 15:15:00', '29.18']
# Data written to CSV: ['2024-05-17 15:30:00', '29.333']
# Data written to CSV: ['2024-05-17 15:45:00', '28.647']
# Data written to CSV: ['2024-05-17 16:00:00', '29.333']
# Data written to CSV: ['2024-05-17 16:15:00', '29.487']
# Data written to CSV: ['2024-05-17 16:30:00', '29.487']
# Data written to CSV: ['2024-05-17 16:45:00', '29.18']
# Data written to CSV: ['2024-05-17 17:00:00', '29.41']
# Data written to CSV: ['2024-05-17 17:15:00', '28.875']
# Data written to CSV: ['2024-05-17 17:30:00', '28.799']
# Data written to CSV: ['2024-05-17 17:45:00', '29.333']
# Data written to CSV: ['2024-05-17 18:00:00', '29.949']
# Data written to CSV: ['2024-05-17 18:15:00', '29.487']
# Data written to CSV: ['2024-05-17 18:30:00', '29.564']
# Data written to CSV: ['2024-05-17 18:45:00', '30.027']
# Data written to CSV: ['2024-05-17 19:00:00', '28.875']
# Data written to CSV: ['2024-05-17 19:15:00', '29.333']
# Data written to CSV: ['2024-05-17 19:30:00', '28.647']
# Data written to CSV: ['2024-05-17 19:45:00', '29.41']
# Data written to CSV: ['2024-05-17 20:00:00', '29.104']
# Data written to CSV: ['2024-05-17 20:15:00', '29.487']
# Data written to CSV: ['2024-05-17 20:30:00', '29.18']
# Data written to CSV: ['2024-05-17 20:45:00', '29.41']
# Data written to CSV: ['2024-05-17 21:00:00', '29.564']
# Data written to CSV: ['2024-05-17 21:15:00', '29.333']
# Data written to CSV: ['2024-05-17 21:30:00', '29.333']
# Data written to CSV: ['2024-05-17 21:45:00', '29.718']
# Data written to CSV: ['2024-05-17 22:00:00', '29.641']
# Data written to CSV: ['2024-05-17 22:15:00', '30.104']
# Data written to CSV: ['2024-05-17 22:30:00', '28.951']
# Data written to CSV: ['2024-05-17 22:45:00', '29.18']
# Data written to CSV: ['2024-05-17 23:00:00', '29.41']
# Data written to CSV: ['2024-05-17 23:15:00', '29.18']
# Data written to CSV: ['2024-05-17 23:30:00', '29.564']
# Data written to CSV: ['2024-05-17 23:45:00', '29.333']
# Data written to CSV: ['2024-05-18 00:00:00', '29.18']
# Data written to CSV: ['2024-05-18 00:15:00', '29.718']
# Data written to CSV: ['2024-05-18 00:30:00', '29.18']
# Data written to CSV: ['2024-05-18 00:45:00', '29.718']
# Data written to CSV: ['2024-05-18 01:00:00', '29.718']
# Data written to CSV: ['2024-05-18 01:15:00', '28.647']
# Data written to CSV: ['2024-05-18 01:30:00', '30.648']
# Data written to CSV: ['2024-05-18 01:45:00', '29.718']
# Data written to CSV: ['2024-05-18 02:00:00', '29.104']
# Data written to CSV: ['2024-05-18 02:15:00', '28.119']
# Data written to CSV: ['2024-05-18 02:30:00', '29.18']
# Data written to CSV: ['2024-05-18 02:45:00', '29.41']
# Data written to CSV: ['2024-05-18 03:00:00', '28.799']
# Data written to CSV: ['2024-05-18 03:15:00', '29.18']
# Data written to CSV: ['2024-05-18 03:30:00', '28.799']
# Data written to CSV: ['2024-05-18 03:45:00', '29.18']
# Data written to CSV: ['2024-05-18 04:00:00', '29.949']
# Data written to CSV: ['2024-05-18 04:15:00', '29.333']
# Data written to CSV: ['2024-05-18 04:30:00', '29.487']
# Data written to CSV: ['2024-05-18 04:45:00', '29.333']
# Data written to CSV: ['2024-05-18 05:00:00', '29.18']
# Data written to CSV: ['2024-05-18 05:15:00', '29.718']
# Data written to CSV: ['2024-05-18 05:30:00', '28.875']
# Data written to CSV: ['2024-05-18 05:45:00', '29.487']
# Data written to CSV: ['2024-05-18 06:00:00', '29.487']
# Data written to CSV: ['2024-05-18 06:15:00', '29.949']
# Data written to CSV: ['2024-05-18 06:30:00', '29.18']
# Data written to CSV: ['2024-05-18 06:45:00', '29.18']
# Data written to CSV: ['2024-05-18 07:00:00', '29.18']
# Data written to CSV: ['2024-05-18 07:15:00', '29.333']
# Data written to CSV: ['2024-05-18 07:30:00', '29.718']
# Data written to CSV: ['2024-05-18 07:45:00', '28.951']
# Data written to CSV: ['2024-05-18 08:00:00', '29.872']
# Data written to CSV: ['2024-05-18 08:15:00', '29.487']
# Data written to CSV: ['2024-05-18 08:30:00', '29.641']
# Data written to CSV: ['2024-05-18 08:45:00', '29.18']
# Data written to CSV: ['2024-05-18 09:00:00', '29.487']
# Data written to CSV: ['2024-05-18 09:15:00', '29.872']
# Data written to CSV: ['2024-05-18 09:30:00', '28.951']
# Data written to CSV: ['2024-05-18 09:45:00', '29.718']
# Data written to CSV: ['2024-05-18 10:00:00', '29.18']
# Data written to CSV: ['2024-05-18 10:15:00', '29.333']
# Data written to CSV: ['2024-05-18 10:30:00', '29.104']
# Data written to CSV: ['2024-05-18 10:45:00', '30.104']
# Data written to CSV: ['2024-05-18 11:00:00', '29.718']
# Data written to CSV: ['2024-05-18 11:15:00', '29.41']
# Data written to CSV: ['2024-05-18 11:30:00', '29.41']
# Data written to CSV: ['2024-05-18 11:45:00', '29.564']
# Data written to CSV: ['2024-05-18 12:00:00', '29.104']
# Data written to CSV: ['2024-05-18 12:15:00', '29.18']
# Data written to CSV: ['2024-05-18 12:30:00', '30.027']
# Data written to CSV: ['2024-05-18 12:45:00', '29.641']
# Data written to CSV: ['2024-05-18 13:00:00', '29.641']
# Data written to CSV: ['2024-05-18 13:15:00', '29.718']
# Data written to CSV: ['2024-05-18 13:30:00', '29.104']
# Data written to CSV: ['2024-05-18 13:45:00', '29.949']
# Data written to CSV: ['2024-05-18 14:00:00', '29.641']
# Data written to CSV: ['2024-05-18 14:15:00', '29.18']
# Data written to CSV: ['2024-05-18 14:30:00', '29.104']
# Data written to CSV: ['2024-05-18 14:45:00', '28.951']
# Data written to CSV: ['2024-05-18 15:00:00', '29.487']
# Data written to CSV: ['2024-05-18 15:15:00', '29.718']
# Data written to CSV: ['2024-05-18 15:30:00', '29.718']
# Data written to CSV: ['2024-05-18 15:45:00', '28.951']
# Data written to CSV: ['2024-05-18 16:00:00', '28.496']
# Data written to CSV: ['2024-05-18 16:15:00', '30.027']
# Data written to CSV: ['2024-05-18 16:30:00', '30.492']
# Data written to CSV: ['2024-05-18 16:45:00', '29.564']
# Data written to CSV: ['2024-05-18 17:00:00', '29.333']
# Data written to CSV: ['2024-05-18 17:15:00', '28.799']
# Data written to CSV: ['2024-05-18 17:30:00', '29.104']
# Data written to CSV: ['2024-05-18 17:45:00', '29.41']
# Data written to CSV: ['2024-05-18 18:00:00', '29.41']
# Data written to CSV: ['2024-05-18 18:15:00', '29.641']
# Data written to CSV: ['2024-05-18 18:30:00', '28.951']
# Data written to CSV: ['2024-05-18 18:45:00', '28.647']
# Data written to CSV: ['2024-05-18 19:00:00', '29.641']
# Data written to CSV: ['2024-05-18 19:15:00', '28.647']
# Data written to CSV: ['2024-05-18 19:30:00', '28.496']
# Data written to CSV: ['2024-05-18 19:45:00', '29.18']
# Data written to CSV: ['2024-05-18 20:00:00', '28.496']
# Data written to CSV: ['2024-05-18 20:15:00', '28.875']
# Data written to CSV: ['2024-05-18 20:30:00', '28.496']
# Data written to CSV: ['2024-05-18 20:45:00', '28.799']
# Data written to CSV: ['2024-05-18 21:00:00', '29.18']
# Data written to CSV: ['2024-05-18 21:15:00', '28.951']
# Data written to CSV: ['2024-05-18 21:30:00', '29.333']
# Data written to CSV: ['2024-05-18 21:45:00', '29.18']
# Data written to CSV: ['2024-05-18 22:00:00', '28.951']
# Data written to CSV: ['2024-05-18 22:15:00', '29.18']
# Data written to CSV: ['2024-05-18 22:30:00', '29.41']
# Data written to CSV: ['2024-05-18 22:45:00', '29.718']
# Data written to CSV: ['2024-05-18 23:00:00', '29.487']
# Data written to CSV: ['2024-05-18 23:15:00', '27.744']
# Data written to CSV: ['2024-05-18 23:30:00', '28.951']
# Data written to CSV: ['2024-05-18 23:45:00', '28.951']
# Data written to CSV: ['2024-05-19 00:00:00', '28.647']
# Data written to CSV: ['2024-05-19 00:15:00', '28.647']
# Data written to CSV: ['2024-05-19 00:30:00', '28.951']
# Data written to CSV: ['2024-05-19 00:45:00', '28.647']
# Data written to CSV: ['2024-05-19 01:00:00', '28.799']
# Data written to CSV: ['2024-05-19 01:15:00', '28.951']
# Data written to CSV: ['2024-05-19 01:30:00', '29.641']
# Data written to CSV: ['2024-05-19 01:45:00', '29.18']
# Data written to CSV: ['2024-05-19 02:00:00', '28.799']
# Data written to CSV: ['2024-05-19 02:15:00', '29.18']
# Data written to CSV: ['2024-05-19 02:30:00', '28.951']
# Data written to CSV: ['2024-05-19 02:45:00', '29.333']
# Data written to CSV: ['2024-05-19 03:00:00', '28.799']
# Data written to CSV: ['2024-05-19 03:15:00', '28.647']
# Data written to CSV: ['2024-05-19 03:30:00', '28.951']
# Data written to CSV: ['2024-05-19 03:45:00', '29.18']
# Data written to CSV: ['2024-05-19 04:00:00', '28.799']
# Data written to CSV: ['2024-05-19 04:15:00', '29.333']
# Data written to CSV: ['2024-05-19 04:30:00', '28.951']
# Data written to CSV: ['2024-05-19 04:45:00', '28.799']
# Data written to CSV: ['2024-05-19 05:00:00', '28.647']
# Data written to CSV: ['2024-05-19 05:15:00', '28.496']
# Data written to CSV: ['2024-05-19 05:30:00', '28.799']
# Data written to CSV: ['2024-05-19 05:45:00', '29.18']
# Data written to CSV: ['2024-05-19 06:00:00', '29.104']
# Data written to CSV: ['2024-05-19 06:15:00', '28.951']
# Data written to CSV: ['2024-05-19 06:30:00', '29.18']
# Data written to CSV: ['2024-05-19 06:45:00', '29.18']
# Data written to CSV: ['2024-05-19 07:00:00', '28.799']
# Data written to CSV: ['2024-05-19 07:15:00', '28.647']
# Data written to CSV: ['2024-05-19 07:30:00', '28.496']
# Data written to CSV: ['2024-05-19 07:45:00', '29.18']
# Data written to CSV: ['2024-05-19 08:00:00', '29.333']
# Data written to CSV: ['2024-05-19 08:15:00', '28.496']
# Data written to CSV: ['2024-05-19 08:30:00', '28.951']
# Data written to CSV: ['2024-05-19 08:45:00', '28.951']
# Data written to CSV: ['2024-05-19 09:00:00', '28.875']
# Data written to CSV: ['2024-05-19 09:15:00', '28.647']
# Data written to CSV: ['2024-05-19 09:30:00', '29.18']
# Data written to CSV: ['2024-05-19 09:45:00', '28.269']
# Data written to CSV: ['2024-05-19 10:00:00', '28.951']
# Data written to CSV: ['2024-05-19 10:15:00', '28.647']
# Data written to CSV: ['2024-05-19 10:30:00', '28.647']
# Data written to CSV: ['2024-05-19 10:45:00', '28.496']
# Data written to CSV: ['2024-05-19 11:00:00', '28.194']
# Data written to CSV: ['2024-05-19 11:15:00', '28.799']
# Data written to CSV: ['2024-05-19 11:30:00', '28.951']
# Data written to CSV: ['2024-05-19 11:45:00', '28.647']
# Data written to CSV: ['2024-05-19 12:00:00', '28.345']
# Data written to CSV: ['2024-05-19 12:15:00', '28.647']
# Data written to CSV: ['2024-05-19 12:30:00', '28.875']
# Data written to CSV: ['2024-05-19 12:45:00', '28.647']
# Data written to CSV: ['2024-05-19 13:00:00', '28.496']
# Data written to CSV: ['2024-05-19 13:15:00', '29.487']
# Data written to CSV: ['2024-05-19 13:30:00', '28.496']
# Data written to CSV: ['2024-05-19 13:45:00', '28.875']
# Data written to CSV: ['2024-05-19 14:00:00', '27.893']
# Data written to CSV: ['2024-05-19 14:15:00', '28.647']
# Data written to CSV: ['2024-05-19 14:30:00', '28.345']
# Data written to CSV: ['2024-05-19 14:45:00', '28.345']
# Data written to CSV: ['2024-05-19 15:00:00', '28.345']
# Data written to CSV: ['2024-05-19 15:15:00', '28.496']
# Data written to CSV: ['2024-05-19 15:30:00', '27.818']
# Data written to CSV: ['2024-05-19 15:45:00', '28.194']
# Data written to CSV: ['2024-05-19 16:00:00', '28.42']
# Data written to CSV: ['2024-05-19 16:15:00', '28.647']
# Data written to CSV: ['2024-05-19 16:30:00', '28.194']
# Data written to CSV: ['2024-05-19 16:45:00', '27.968']
# Data written to CSV: ['2024-05-19 17:00:00', '28.42']
# Data written to CSV: ['2024-05-19 17:15:00', '28.496']
# Data written to CSV: ['2024-05-19 17:30:00', '28.42']
# Data written to CSV: ['2024-05-19 17:45:00', '28.799']
# Data written to CSV: ['2024-05-19 18:00:00', '28.42']
# Data written to CSV: ['2024-05-19 18:15:00', '28.647']
# Data written to CSV: ['2024-05-19 18:30:00', '28.345']
# Data written to CSV: ['2024-05-19 18:45:00', '28.799']
# Data written to CSV: ['2024-05-19 19:00:00', '28.269']
# Data written to CSV: ['2024-05-19 19:15:00', '28.119']
# Data written to CSV: ['2024-05-19 19:30:00', '28.42']
# Data written to CSV: ['2024-05-19 19:45:00', '29.104']
# Data written to CSV: ['2024-05-19 20:00:00', '28.799']
# Data written to CSV: ['2024-05-19 20:15:00', '28.951']
# Data written to CSV: ['2024-05-19 20:30:00', '28.875']
# Data written to CSV: ['2024-05-19 20:45:00', '28.647']
# Data written to CSV: ['2024-05-19 21:00:00', '28.799']
# Data written to CSV: ['2024-05-19 21:15:00', '28.875']
# Data written to CSV: ['2024-05-19 21:30:00', '28.194']
# Data written to CSV: ['2024-05-19 21:45:00', '28.799']
# Data written to CSV: ['2024-05-19 22:00:00', '28.496']
# Data written to CSV: ['2024-05-19 22:15:00', '27.893']
# Data written to CSV: ['2024-05-19 22:30:00', '28.043']
# Data written to CSV: ['2024-05-19 22:45:00', '28.345']
# Data written to CSV: ['2024-05-19 23:00:00', '28.345']
# Data written to CSV: ['2024-05-19 23:15:00', '28.119']
# Data written to CSV: ['2024-05-19 23:30:00', '28.345']
# Data written to CSV: ['2024-05-19 23:45:00', '27.744']
# Data written to CSV: ['2024-05-20 00:00:00', '28.42']
# Data written to CSV: ['2024-05-20 00:15:00', '28.496']
# Data written to CSV: ['2024-05-20 00:30:00', '28.496']
# Data written to CSV: ['2024-05-20 00:45:00', '28.043']
# Data written to CSV: ['2024-05-20 01:00:00', '28.269']
# Data written to CSV: ['2024-05-20 01:15:00', '28.345']
# Data written to CSV: ['2024-05-20 01:30:00', '28.043']
# Data written to CSV: ['2024-05-20 01:45:00', '27.445']
# Data written to CSV: ['2024-05-20 02:00:00', '28.951']
# Data written to CSV: ['2024-05-20 02:15:00', '27.968']
# Data written to CSV: ['2024-05-20 02:30:00', '28.496']
# Data written to CSV: ['2024-05-20 02:45:00', '27.968']
# Data written to CSV: ['2024-05-20 03:00:00', '27.669']
# Data written to CSV: ['2024-05-20 03:15:00', '28.119']
# Data written to CSV: ['2024-05-20 03:30:00', '28.345']
# Data written to CSV: ['2024-05-20 03:45:00', '28.119']
# Data written to CSV: ['2024-05-20 04:00:00', '27.744']
# Data written to CSV: ['2024-05-20 04:15:00', '27.968']
# Data written to CSV: ['2024-05-20 04:30:00', '28.496']
# Data written to CSV: ['2024-05-20 04:45:00', '28.043']
# Data written to CSV: ['2024-05-20 05:00:00', '28.42']
# Data written to CSV: ['2024-05-20 05:15:00', '27.445']
# Data written to CSV: ['2024-05-20 05:30:00', '28.043']
# Data written to CSV: ['2024-05-20 05:45:00', '28.043']
# Data written to CSV: ['2024-05-20 06:00:00', '28.043']
# Data written to CSV: ['2024-05-20 06:15:00', '28.043']
# Data written to CSV: ['2024-05-20 06:30:00', '27.222']
# Data written to CSV: ['2024-05-20 06:45:00', '28.345']
# Data written to CSV: ['2024-05-20 07:00:00', '27.818']
# Data written to CSV: ['2024-05-20 07:15:00', '28.496']
# Data written to CSV: ['2024-05-20 07:30:00', '27.893']
# Data written to CSV: ['2024-05-20 07:45:00', '27.818']
# Data written to CSV: ['2024-05-20 08:00:00', '28.345']
# Data written to CSV: ['2024-05-20 08:15:00', '27.893']
# Data written to CSV: ['2024-05-20 08:30:00', '28.043']
# Data written to CSV: ['2024-05-20 08:45:00', '27.669']
# Data written to CSV: ['2024-05-20 09:00:00', '28.194']
# Data written to CSV: ['2024-05-20 09:15:00', '27.594']
# Data written to CSV: ['2024-05-20 09:30:00', '27.669']
# Data written to CSV: ['2024-05-20 09:45:00', '28.42']
# Data written to CSV: ['2024-05-20 10:00:00', '27.893']
# Data written to CSV: ['2024-05-20 10:15:00', '27.893']
# Data written to CSV: ['2024-05-20 10:30:00', '27.968']
# Data written to CSV: ['2024-05-20 10:45:00', '28.194']
# Data written to CSV: ['2024-05-20 11:00:00', '28.043']
# Data written to CSV: ['2024-05-20 11:15:00', '27.968']
# Data written to CSV: ['2024-05-20 11:30:00', '28.345']
# Data written to CSV: ['2024-05-20 11:45:00', '28.269']
# Data written to CSV: ['2024-05-20 12:00:00', '27.371']
# Data written to CSV: ['2024-05-20 12:15:00', '27.893']
# Data written to CSV: ['2024-05-20 12:30:00', '27.968']
# Data written to CSV: ['2024-05-20 12:45:00', '28.043']
# Data written to CSV: ['2024-05-20 13:00:00', '27.968']
# Data written to CSV: ['2024-05-20 13:15:00', '27.893']
# Data written to CSV: ['2024-05-20 13:30:00', '27.222']
# Data written to CSV: ['2024-05-20 13:45:00', '27.445']
# Data written to CSV: ['2024-05-20 14:00:00', '27.669']
# Data written to CSV: ['2024-05-20 14:15:00', '28.194']
# Data written to CSV: ['2024-05-20 14:30:00', '27.744']
# Data written to CSV: ['2024-05-20 14:45:00', '27.445']
# Data written to CSV: ['2024-05-20 15:00:00', '27.296']
# Data written to CSV: ['2024-05-20 15:15:00', '27.669']
# Data written to CSV: ['2024-05-20 15:30:00', '27.445']
# Data written to CSV: ['2024-05-20 15:45:00', '27.0']
# Data written to CSV: ['2024-05-20 16:00:00', '27.594']
# Data written to CSV: ['2024-05-20 16:15:00', '27.371']
# Data written to CSV: ['2024-05-20 16:30:00', '27.0']
# Data written to CSV: ['2024-05-20 16:45:00', '27.222']
# Data written to CSV: ['2024-05-20 17:00:00', '28.043']
# Closing the connection.
# Connection established. Streaming data...
# Data written to CSV: ['time_format', '%Y-%m-%d %H:%M:%S']
# Data written to CSV: ['tz', 'UTC+01']
# Data written to CSV: ['api_warnings', '']
# Data written to CSV: ['timestamp', 'value']
# Data written to CSV: ['2024-05-14 00:00:00', '5.822']
# Data written to CSV: ['2024-05-14 00:15:00', '5.633']
# Data written to CSV: ['2024-05-14 00:30:00', '5.784']
# Data written to CSV: ['2024-05-14 00:45:00', '5.746']
# Data written to CSV: ['2024-05-14 01:00:00', '5.596']
# Data written to CSV: ['2024-05-14 01:15:00', '5.708']
# Data written to CSV: ['2024-05-14 01:30:00', '5.596']
# Data written to CSV: ['2024-05-14 01:45:00', '5.746']
# Data written to CSV: ['2024-05-14 02:00:00', '5.708']
# Data written to CSV: ['2024-05-14 02:15:00', '5.746']
# Data written to CSV: ['2024-05-14 02:30:00', '5.671']
# Data written to CSV: ['2024-05-14 02:45:00', '5.784']
# Data written to CSV: ['2024-05-14 03:00:00', '5.746']
# Data written to CSV: ['2024-05-14 03:15:00', '5.558']
# Data written to CSV: ['2024-05-14 03:30:00', '5.708']
# Data written to CSV: ['2024-05-14 03:45:00', '5.671']
# Data written to CSV: ['2024-05-14 04:00:00', '5.633']
# Data written to CSV: ['2024-05-14 04:15:00', '5.822']
# Data written to CSV: ['2024-05-14 04:30:00', '5.708']
# Data written to CSV: ['2024-05-14 04:45:00', '5.746']
# Data written to CSV: ['2024-05-14 05:00:00', '5.708']
# Data written to CSV: ['2024-05-14 05:15:00', '5.633']
# Data written to CSV: ['2024-05-14 05:30:00', '5.558']
# Data written to CSV: ['2024-05-14 05:45:00', '5.596']
# Data written to CSV: ['2024-05-14 06:00:00', '5.596']
# Data written to CSV: ['2024-05-14 06:15:00', '5.596']
# Data written to CSV: ['2024-05-14 06:30:00', '9.772']
# Data written to CSV: ['2024-05-14 06:45:00', '13.079']
# Data written to CSV: ['2024-05-14 07:00:00', '13.405']
# Data written to CSV: ['2024-05-14 07:15:00', '14.18']
# Data written to CSV: ['2024-05-14 07:30:00', '14.18']
# Data written to CSV: ['2024-05-14 07:45:00', '14.236']
# Data written to CSV: ['2024-05-14 08:00:00', '14.012']
# Data written to CSV: ['2024-05-14 08:15:00', '14.292']
# Data written to CSV: ['2024-05-14 08:30:00', '14.348']
# Data written to CSV: ['2024-05-14 08:45:00', '14.18']
# Data written to CSV: ['2024-05-14 09:00:00', '14.461']
# Data written to CSV: ['2024-05-14 09:15:00', '14.068']
# Data written to CSV: ['2024-05-14 09:30:00', '14.292']
# Data written to CSV: ['2024-05-14 09:45:00', '13.956']
# Data written to CSV: ['2024-05-14 10:00:00', '14.236']
# Data written to CSV: ['2024-05-14 10:15:00', '13.845']
# Data written to CSV: ['2024-05-14 10:30:00', '13.956']
# Data written to CSV: ['2024-05-14 10:45:00', '14.236']
# Data written to CSV: ['2024-05-14 11:00:00', '14.068']
# Data written to CSV: ['2024-05-14 11:15:00', '13.901']
# Data written to CSV: ['2024-05-14 11:30:00', '13.68']
# Data written to CSV: ['2024-05-14 11:45:00', '13.845']
# Data written to CSV: ['2024-05-14 12:00:00', '13.956']
# Data written to CSV: ['2024-05-14 12:15:00', '14.012']
# Data written to CSV: ['2024-05-14 12:30:00', '14.012']
# Data written to CSV: ['2024-05-14 12:45:00', '13.845']
# Data written to CSV: ['2024-05-14 13:00:00', '13.956']
# Data written to CSV: ['2024-05-14 13:15:00', '15.667']
# Data written to CSV: ['2024-05-14 13:30:00', '16.078']
# Data written to CSV: ['2024-05-14 13:45:00', '15.784']
# Data written to CSV: ['2024-05-14 14:00:00', '16.315']
# Data written to CSV: ['2024-05-14 14:15:00', '16.078']
# Data written to CSV: ['2024-05-14 14:30:00', '15.784']
# Data written to CSV: ['2024-05-14 14:45:00', '16.078']
# Data written to CSV: ['2024-05-14 15:00:00', '15.784']
# Data written to CSV: ['2024-05-14 15:15:00', '15.667']
# Data written to CSV: ['2024-05-14 15:30:00', '15.376']
# Data written to CSV: ['2024-05-14 15:45:00', '16.434']
# Data written to CSV: ['2024-05-14 16:00:00', '15.667']
# Data written to CSV: ['2024-05-14 16:15:00', '15.609']
# Data written to CSV: ['2024-05-14 16:30:00', '16.197']
# Data written to CSV: ['2024-05-14 16:45:00', '16.197']
# Data written to CSV: ['2024-05-14 17:00:00', '16.256']
# Data written to CSV: ['2024-05-14 17:15:00', '16.614']
# Data written to CSV: ['2024-05-14 17:30:00', '16.375']
# Data written to CSV: ['2024-05-14 17:45:00', '16.434']
# Data written to CSV: ['2024-05-14 18:00:00', '16.375']
# Data written to CSV: ['2024-05-14 18:15:00', '16.197']
# Data written to CSV: ['2024-05-14 18:30:00', '16.256']
# Data written to CSV: ['2024-05-14 18:45:00', '16.197']
# Data written to CSV: ['2024-05-14 19:00:00', '16.614']
# Data written to CSV: ['2024-05-14 19:15:00', '16.375']
# Data written to CSV: ['2024-05-14 19:30:00', '16.434']
# Data written to CSV: ['2024-05-14 19:45:00', '16.315']
# Data written to CSV: ['2024-05-14 20:00:00', '16.197']
# Data written to CSV: ['2024-05-14 20:15:00', '16.256']
# Data written to CSV: ['2024-05-14 20:30:00', '16.315']
# Data written to CSV: ['2024-05-14 20:45:00', '16.256']
# Data written to CSV: ['2024-05-14 21:00:00', '16.256']
# Data written to CSV: ['2024-05-14 21:15:00', '16.078']
# Data written to CSV: ['2024-05-14 21:30:00', '16.734']
# Data written to CSV: ['2024-05-14 21:45:00', '16.315']
# Data written to CSV: ['2024-05-14 22:00:00', '15.901']
# Data written to CSV: ['2024-05-14 22:15:00', '16.197']
# Data written to CSV: ['2024-05-14 22:30:00', '16.078']
# Data written to CSV: ['2024-05-14 22:45:00', '16.315']
# Data written to CSV: ['2024-05-14 23:00:00', '16.434']
# Data written to CSV: ['2024-05-14 23:15:00', '16.554']
# Data written to CSV: ['2024-05-14 23:30:00', '16.256']
# Data written to CSV: ['2024-05-14 23:45:00', '16.315']
# Data written to CSV: ['2024-05-15 00:00:00', '16.078']
# Data written to CSV: ['2024-05-15 00:15:00', '16.078']
# Data written to CSV: ['2024-05-15 00:30:00', '16.315']
# Data written to CSV: ['2024-05-15 00:45:00', '16.375']
# Data written to CSV: ['2024-05-15 01:00:00', '16.197']
# Data written to CSV: ['2024-05-15 01:15:00', '16.434']
# Data written to CSV: ['2024-05-15 01:30:00', '16.197']
# Data written to CSV: ['2024-05-15 01:45:00', '16.019']
# Data written to CSV: ['2024-05-15 02:00:00', '15.492']
# Data written to CSV: ['2024-05-15 02:15:00', '16.434']
# Data written to CSV: ['2024-05-15 02:30:00', '15.901']
# Data written to CSV: ['2024-05-15 02:45:00', '16.315']
# Data written to CSV: ['2024-05-15 03:00:00', '16.078']
# Data written to CSV: ['2024-05-15 03:15:00', '16.434']
# Data written to CSV: ['2024-05-15 03:30:00', '16.256']
# Data written to CSV: ['2024-05-15 03:45:00', '16.256']
# Data written to CSV: ['2024-05-15 04:00:00', '16.078']
# Data written to CSV: ['2024-05-15 04:15:00', '16.197']
# Data written to CSV: ['2024-05-15 04:30:00', '16.375']
# Data written to CSV: ['2024-05-15 04:45:00', '16.078']
# Data written to CSV: ['2024-05-15 05:00:00', '16.197']
# Data written to CSV: ['2024-05-15 05:15:00', '16.078']
# Data written to CSV: ['2024-05-15 05:30:00', '15.667']
# Data written to CSV: ['2024-05-15 05:45:00', '16.078']
# Data written to CSV: ['2024-05-15 06:00:00', '16.315']
# Data written to CSV: ['2024-05-15 06:15:00', '16.019']
# Data written to CSV: ['2024-05-15 06:30:00', '16.375']
# Data written to CSV: ['2024-05-15 06:45:00', '15.784']
# Data written to CSV: ['2024-05-15 07:00:00', '15.901']
# Data written to CSV: ['2024-05-15 07:15:00', '15.96']
# Data written to CSV: ['2024-05-15 07:30:00', '16.434']
# Data written to CSV: ['2024-05-15 07:45:00', '16.078']
# Data written to CSV: ['2024-05-15 08:00:00', '16.434']
# Data written to CSV: ['2024-05-15 08:15:00', '16.256']
# Data written to CSV: ['2024-05-15 08:30:00', '16.614']
# Data written to CSV: ['2024-05-15 08:45:00', '16.915']
# Data written to CSV: ['2024-05-15 09:00:00', '16.915']
# Data written to CSV: ['2024-05-15 09:15:00', '16.734']
# Data written to CSV: ['2024-05-15 09:30:00', '16.975']
# Data written to CSV: ['2024-05-15 09:45:00', '16.854']
# Data written to CSV: ['2024-05-15 10:00:00', '17.34']
# Data written to CSV: ['2024-05-15 10:15:00', '17.401']
# Data written to CSV: ['2024-05-15 10:30:00', '17.523']
# Data written to CSV: ['2024-05-15 10:45:00', '18.329']
# Data written to CSV: ['2024-05-15 11:00:00', '18.454']
# Data written to CSV: ['2024-05-15 11:15:00', '18.454']
# Data written to CSV: ['2024-05-15 11:30:00', '18.204']
# Data written to CSV: ['2024-05-15 11:45:00', '18.705']
# Data written to CSV: ['2024-05-15 12:00:00', '18.769']
# Data written to CSV: ['2024-05-15 12:15:00', '18.517']
# Data written to CSV: ['2024-05-15 12:30:00', '18.454']
# Data written to CSV: ['2024-05-15 12:45:00', '18.141']
# Data written to CSV: ['2024-05-15 13:00:00', '18.017']
# Data written to CSV: ['2024-05-15 13:15:00', '18.329']
# Data written to CSV: ['2024-05-15 13:30:00', '17.955']
# Data written to CSV: ['2024-05-15 13:45:00', '17.401']
# Data written to CSV: ['2024-05-15 14:00:00', '17.893']
# Data written to CSV: ['2024-05-15 14:15:00', '18.329']
# Data written to CSV: ['2024-05-15 14:30:00', '18.517']
# Data written to CSV: ['2024-05-15 14:45:00', '18.017']
# Data written to CSV: ['2024-05-15 15:00:00', '18.769']
# Data written to CSV: ['2024-05-15 15:15:00', '19.662']
# Data written to CSV: ['2024-05-15 15:30:00', '19.405']
# Data written to CSV: ['2024-05-15 15:45:00', '18.705']
# Data written to CSV: ['2024-05-15 16:00:00', '18.391']
# Data written to CSV: ['2024-05-15 16:15:00', '18.517']
# Data written to CSV: ['2024-05-15 16:30:00', '18.204']
# Data written to CSV: ['2024-05-15 16:45:00', '18.769']
# Data written to CSV: ['2024-05-15 17:00:00', '18.329']
# Data written to CSV: ['2024-05-15 17:15:00', '18.017']
# Data written to CSV: ['2024-05-15 17:30:00', '18.266']
# Data written to CSV: ['2024-05-15 17:45:00', '18.329']
# Data written to CSV: ['2024-05-15 18:00:00', '18.895']
# Data written to CSV: ['2024-05-15 18:15:00', '18.517']
# Data written to CSV: ['2024-05-15 18:30:00', '18.958']
# Data written to CSV: ['2024-05-15 18:45:00', '19.213']
# Data written to CSV: ['2024-05-15 19:00:00', '19.149']
# Data written to CSV: ['2024-05-15 19:15:00', '19.727']
# Data written to CSV: ['2024-05-15 19:30:00', '20.771']
# Data written to CSV: ['2024-05-15 19:45:00', '21.302']
# Data written to CSV: ['2024-05-15 20:00:00', '21.704']
# Data written to CSV: ['2024-05-15 20:15:00', '22.313']
# Data written to CSV: ['2024-05-15 20:30:00', '23.832']
# Data written to CSV: ['2024-05-15 20:45:00', '23.623']
# Data written to CSV: ['2024-05-15 21:00:00', '23.136']
# Data written to CSV: ['2024-05-15 21:15:00', '25.108']
# Data written to CSV: ['2024-05-15 21:30:00', '26.265']
# Data written to CSV: ['2024-05-15 21:45:00', '22.861']
# Data written to CSV: ['2024-05-15 22:00:00', '21.906']
# Data written to CSV: ['2024-05-15 22:15:00', '21.771']
# Data written to CSV: ['2024-05-15 22:30:00', '24.113']
# Data written to CSV: ['2024-05-15 22:45:00', '23.483']
# Data written to CSV: ['2024-05-15 23:00:00', '25.395']
# Data written to CSV: ['2024-05-15 23:15:00', '24.608']
# Data written to CSV: ['2024-05-15 23:30:00', '23.832']
# Data written to CSV: ['2024-05-15 23:45:00', '23.973']
# Data written to CSV: ['2024-05-16 00:00:00', '23.692']
# Data written to CSV: ['2024-05-16 00:15:00', '22.723']
# Data written to CSV: ['2024-05-16 00:30:00', '22.313']
# Data written to CSV: ['2024-05-16 00:45:00', '21.771']
# Data written to CSV: ['2024-05-16 01:00:00', '22.518']
# Data written to CSV: ['2024-05-16 01:15:00', '21.771']
# Data written to CSV: ['2024-05-16 01:30:00', '22.109']
# Data written to CSV: ['2024-05-16 01:45:00', '22.245']
# Data written to CSV: ['2024-05-16 02:00:00', '22.381']
# Data written to CSV: ['2024-05-16 02:15:00', '22.177']
# Data written to CSV: ['2024-05-16 02:30:00', '22.109']
# Data written to CSV: ['2024-05-16 02:45:00', '22.313']
# Data written to CSV: ['2024-05-16 03:00:00', '22.177']
# Data written to CSV: ['2024-05-16 03:15:00', '22.449']
# Data written to CSV: ['2024-05-16 03:30:00', '22.655']
# Data written to CSV: ['2024-05-16 03:45:00', '22.861']
# Data written to CSV: ['2024-05-16 04:00:00', '22.861']
# Data written to CSV: ['2024-05-16 04:15:00', '22.177']
# Data written to CSV: ['2024-05-16 04:30:00', '22.177']
# Data written to CSV: ['2024-05-16 04:45:00', '22.586']
# Data written to CSV: ['2024-05-16 05:00:00', '22.449']
# Data written to CSV: ['2024-05-16 05:15:00', '22.245']
# Data written to CSV: ['2024-05-16 05:30:00', '22.586']
# Data written to CSV: ['2024-05-16 05:45:00', '23.136']
# Data written to CSV: ['2024-05-16 06:00:00', '22.861']
# Data written to CSV: ['2024-05-16 06:15:00', '22.381']
# Data written to CSV: ['2024-05-16 06:30:00', '22.998']
# Data written to CSV: ['2024-05-16 06:45:00', '22.655']
# Data written to CSV: ['2024-05-16 07:00:00', '23.067']
# ...
# Data written to CSV: ['2024-05-17 18:00:00', '29.949']
# Data written to CSV: ['2024-05-17 18:15:00', '29.487']
# Data written to CSV: ['2024-05-17 18:30:00', '29.564']
# Data written to CSV: ['2024-05-17 18:45:00', '30.027']
# Data written to CSV: ['2024-05-17 19:00:00', '28.875']
# Data written to CSV: ['2024-05-17 19:15:00', '29.333']
# Data written to CSV: ['2024-05-17 19:30:00', '28.647']
# Data written to CSV: ['2024-05-17 19:45:00', '29.41']
# Data written to CSV: ['2024-05-17 20:00:00', '29.104']
# Data written to CSV: ['2024-05-17 20:15:00', '29.487']
# Data written to CSV: ['2024-05-17 20:30:00', '29.18']
# Data written to CSV: ['2024-05-17 20:45:00', '29.41']
# Data written to CSV: ['2024-05-17 21:00:00', '29.564']
# Data written to CSV: ['2024-05-17 21:15:00', '29.333']
# Data written to CSV: ['2024-05-17 21:30:00', '29.333']
# Data written to CSV: ['2024-05-17 21:45:00', '29.718']
# Data written to CSV: ['2024-05-17 22:00:00', '29.641']
# Data written to CSV: ['2024-05-17 22:15:00', '30.104']
# Data written to CSV: ['2024-05-17 22:30:00', '28.951']
# Data written to CSV: ['2024-05-17 22:45:00', '29.18']
# Data written to CSV: ['2024-05-17 23:00:00', '29.41']
# Data written to CSV: ['2024-05-17 23:15:00', '29.18']
# Data written to CSV: ['2024-05-17 23:30:00', '29.564']
# Data written to CSV: ['2024-05-17 23:45:00', '29.333']
# Data written to CSV: ['2024-05-18 00:00:00', '29.18']
# Data written to CSV: ['2024-05-18 00:15:00', '29.718']
# Data written to CSV: ['2024-05-18 00:30:00', '29.18']
# Data written to CSV: ['2024-05-18 00:45:00', '29.718']
# Data written to CSV: ['2024-05-18 01:00:00', '29.718']
# Data written to CSV: ['2024-05-18 01:15:00', '28.647']
# Data written to CSV: ['2024-05-18 01:30:00', '30.648']
# Data written to CSV: ['2024-05-18 01:45:00', '29.718']
# Data written to CSV: ['2024-05-18 02:00:00', '29.104']
# Data written to CSV: ['2024-05-18 02:15:00', '28.119']
# Data written to CSV: ['2024-05-18 02:30:00', '29.18']
# Data written to CSV: ['2024-05-18 02:45:00', '29.41']
# Data written to CSV: ['2024-05-18 03:00:00', '28.799']
# Data written to CSV: ['2024-05-18 03:15:00', '29.18']
# Data written to CSV: ['2024-05-18 03:30:00', '28.799']
# Data written to CSV: ['2024-05-18 03:45:00', '29.18']
# Data written to CSV: ['2024-05-18 04:00:00', '29.949']
# Data written to CSV: ['2024-05-18 04:15:00', '29.333']
# Data written to CSV: ['2024-05-18 04:30:00', '29.487']
# Data written to CSV: ['2024-05-18 04:45:00', '29.333']
# Data written to CSV: ['2024-05-18 05:00:00', '29.18']
# Data written to CSV: ['2024-05-18 05:15:00', '29.718']
# Data written to CSV: ['2024-05-18 05:30:00', '28.875']
# Data written to CSV: ['2024-05-18 05:45:00', '29.487']
# Data written to CSV: ['2024-05-18 06:00:00', '29.487']
# Data written to CSV: ['2024-05-18 06:15:00', '29.949']
# Data written to CSV: ['2024-05-18 06:30:00', '29.18']
# Data written to CSV: ['2024-05-18 06:45:00', '29.18']
# Data written to CSV: ['2024-05-18 07:00:00', '29.18']
# Data written to CSV: ['2024-05-18 07:15:00', '29.333']
# Data written to CSV: ['2024-05-18 07:30:00', '29.718']
# Data written to CSV: ['2024-05-18 07:45:00', '28.951']
# Data written to CSV: ['2024-05-18 08:00:00', '29.872']
# Data written to CSV: ['2024-05-18 08:15:00', '29.487']
# Data written to CSV: ['2024-05-18 08:30:00', '29.641']
# Data written to CSV: ['2024-05-18 08:45:00', '29.18']
# Data written to CSV: ['2024-05-18 09:00:00', '29.487']
# Data written to CSV: ['2024-05-18 09:15:00', '29.872']
# Data written to CSV: ['2024-05-18 09:30:00', '28.951']
# Data written to CSV: ['2024-05-18 09:45:00', '29.718']
# Data written to CSV: ['2024-05-18 10:00:00', '29.18']
# Data written to CSV: ['2024-05-18 10:15:00', '29.333']
# Data written to CSV: ['2024-05-18 10:30:00', '29.104']
# Data written to CSV: ['2024-05-18 10:45:00', '30.104']
# Data written to CSV: ['2024-05-18 11:00:00', '29.718']
# Data written to CSV: ['2024-05-18 11:15:00', '29.41']
# Data written to CSV: ['2024-05-18 11:30:00', '29.41']
# Data written to CSV: ['2024-05-18 11:45:00', '29.564']
# Data written to CSV: ['2024-05-18 12:00:00', '29.104']
# Data written to CSV: ['2024-05-18 12:15:00', '29.18']
# Data written to CSV: ['2024-05-18 12:30:00', '30.027']
# Data written to CSV: ['2024-05-18 12:45:00', '29.641']
# Data written to CSV: ['2024-05-18 13:00:00', '29.641']
# Data written to CSV: ['2024-05-18 13:15:00', '29.718']
# Data written to CSV: ['2024-05-18 13:30:00', '29.104']
# Data written to CSV: ['2024-05-18 13:45:00', '29.949']
# Data written to CSV: ['2024-05-18 14:00:00', '29.641']
# Data written to CSV: ['2024-05-18 14:15:00', '29.18']
# Data written to CSV: ['2024-05-18 14:30:00', '29.104']
# Data written to CSV: ['2024-05-18 14:45:00', '28.951']
# Data written to CSV: ['2024-05-18 15:00:00', '29.487']
# Data written to CSV: ['2024-05-18 15:15:00', '29.718']
# Data written to CSV: ['2024-05-18 15:30:00', '29.718']
# Data written to CSV: ['2024-05-18 15:45:00', '28.951']
# Data written to CSV: ['2024-05-18 16:00:00', '28.496']
# Data written to CSV: ['2024-05-18 16:15:00', '30.027']
# Data written to CSV: ['2024-05-18 16:30:00', '30.492']
# Data written to CSV: ['2024-05-18 16:45:00', '29.564']
# Data written to CSV: ['2024-05-18 17:00:00', '29.333']
# Data written to CSV: ['2024-05-18 17:15:00', '28.799']
# Data written to CSV: ['2024-05-18 17:30:00', '29.104']
# Data written to CSV: ['2024-05-18 17:45:00', '29.41']
# Data written to CSV: ['2024-05-18 18:00:00', '29.41']
# Data written to CSV: ['2024-05-18 18:15:00', '29.641']
# Data written to CSV: ['2024-05-18 18:30:00', '28.951']
# Data written to CSV: ['2024-05-18 18:45:00', '28.647']
# Data written to CSV: ['2024-05-18 19:00:00', '29.641']
# Data written to CSV: ['2024-05-18 19:15:00', '28.647']
# Data written to CSV: ['2024-05-18 19:30:00', '28.496']
# Data written to CSV: ['2024-05-18 19:45:00', '29.18']
# Data written to CSV: ['2024-05-18 20:00:00', '28.496']
# Data written to CSV: ['2024-05-18 20:15:00', '28.875']
# Data written to CSV: ['2024-05-18 20:30:00', '28.496']
# Data written to CSV: ['2024-05-18 20:45:00', '28.799']
# Data written to CSV: ['2024-05-18 21:00:00', '29.18']
# Data written to CSV: ['2024-05-18 21:15:00', '28.951']
# Data written to CSV: ['2024-05-18 21:30:00', '29.333']
# Data written to CSV: ['2024-05-18 21:45:00', '29.18']
# Data written to CSV: ['2024-05-18 22:00:00', '28.951']
# Data written to CSV: ['2024-05-18 22:15:00', '29.18']
# Data written to CSV: ['2024-05-18 22:30:00', '29.41']
# Data written to CSV: ['2024-05-18 22:45:00', '29.718']
# Data written to CSV: ['2024-05-18 23:00:00', '29.487']
# Data written to CSV: ['2024-05-18 23:15:00', '27.744']
# Data written to CSV: ['2024-05-18 23:30:00', '28.951']
# Data written to CSV: ['2024-05-18 23:45:00', '28.951']
# Data written to CSV: ['2024-05-19 00:00:00', '28.647']
# Data written to CSV: ['2024-05-19 00:15:00', '28.647']
# Data written to CSV: ['2024-05-19 00:30:00', '28.951']
# Data written to CSV: ['2024-05-19 00:45:00', '28.647']
# Data written to CSV: ['2024-05-19 01:00:00', '28.799']
# Data written to CSV: ['2024-05-19 01:15:00', '28.951']
# Data written to CSV: ['2024-05-19 01:30:00', '29.641']
# Data written to CSV: ['2024-05-19 01:45:00', '29.18']
# Data written to CSV: ['2024-05-19 02:00:00', '28.799']
# Data written to CSV: ['2024-05-19 02:15:00', '29.18']
# Data written to CSV: ['2024-05-19 02:30:00', '28.951']
# Data written to CSV: ['2024-05-19 02:45:00', '29.333']
# Data written to CSV: ['2024-05-19 03:00:00', '28.799']
# Data written to CSV: ['2024-05-19 03:15:00', '28.647']
# Data written to CSV: ['2024-05-19 03:30:00', '28.951']
# Data written to CSV: ['2024-05-19 03:45:00', '29.18']
# Data written to CSV: ['2024-05-19 04:00:00', '28.799']
# Data written to CSV: ['2024-05-19 04:15:00', '29.333']
# Data written to CSV: ['2024-05-19 04:30:00', '28.951']
# Data written to CSV: ['2024-05-19 04:45:00', '28.799']
# Data written to CSV: ['2024-05-19 05:00:00', '28.647']
# Data written to CSV: ['2024-05-19 05:15:00', '28.496']
# Data written to CSV: ['2024-05-19 05:30:00', '28.799']
# Data written to CSV: ['2024-05-19 05:45:00', '29.18']
# Data written to CSV: ['2024-05-19 06:00:00', '29.104']
# Data written to CSV: ['2024-05-19 06:15:00', '28.951']
# Data written to CSV: ['2024-05-19 06:30:00', '29.18']
# Data written to CSV: ['2024-05-19 06:45:00', '29.18']
# Data written to CSV: ['2024-05-19 07:00:00', '28.799']
# Data written to CSV: ['2024-05-19 07:15:00', '28.647']
# Data written to CSV: ['2024-05-19 07:30:00', '28.496']
# Data written to CSV: ['2024-05-19 07:45:00', '29.18']
# Data written to CSV: ['2024-05-19 08:00:00', '29.333']
# Data written to CSV: ['2024-05-19 08:15:00', '28.496']
# Data written to CSV: ['2024-05-19 08:30:00', '28.951']
# Data written to CSV: ['2024-05-19 08:45:00', '28.951']
# Data written to CSV: ['2024-05-19 09:00:00', '28.875']
# Data written to CSV: ['2024-05-19 09:15:00', '28.647']
# Data written to CSV: ['2024-05-19 09:30:00', '29.18']
# Data written to CSV: ['2024-05-19 09:45:00', '28.269']
# Data written to CSV: ['2024-05-19 10:00:00', '28.951']
# Data written to CSV: ['2024-05-19 10:15:00', '28.647']
# Data written to CSV: ['2024-05-19 10:30:00', '28.647']
# Data written to CSV: ['2024-05-19 10:45:00', '28.496']
# Data written to CSV: ['2024-05-19 11:00:00', '28.194']
# Data written to CSV: ['2024-05-19 11:15:00', '28.799']
# Data written to CSV: ['2024-05-19 11:30:00', '28.951']
# Data written to CSV: ['2024-05-19 11:45:00', '28.647']
# Data written to CSV: ['2024-05-19 12:00:00', '28.345']
# Data written to CSV: ['2024-05-19 12:15:00', '28.647']
# Data written to CSV: ['2024-05-19 12:30:00', '28.875']
# Data written to CSV: ['2024-05-19 12:45:00', '28.647']
# Data written to CSV: ['2024-05-19 13:00:00', '28.496']
# Data written to CSV: ['2024-05-19 13:15:00', '29.487']
# Data written to CSV: ['2024-05-19 13:30:00', '28.496']
# Data written to CSV: ['2024-05-19 13:45:00', '28.875']
# Data written to CSV: ['2024-05-19 14:00:00', '27.893']
# Data written to CSV: ['2024-05-19 14:15:00', '28.647']
# Data written to CSV: ['2024-05-19 14:30:00', '28.345']
# Data written to CSV: ['2024-05-19 14:45:00', '28.345']
# Data written to CSV: ['2024-05-19 15:00:00', '28.345']
# Data written to CSV: ['2024-05-19 15:15:00', '28.496']
# Data written to CSV: ['2024-05-19 15:30:00', '27.818']
# Data written to CSV: ['2024-05-19 15:45:00', '28.194']
# Data written to CSV: ['2024-05-19 16:00:00', '28.42']
# Data written to CSV: ['2024-05-19 16:15:00', '28.647']
# Data written to CSV: ['2024-05-19 16:30:00', '28.194']
# Data written to CSV: ['2024-05-19 16:45:00', '27.968']
# Data written to CSV: ['2024-05-19 17:00:00', '28.42']
# Data written to CSV: ['2024-05-19 17:15:00', '28.496']
# Data written to CSV: ['2024-05-19 17:30:00', '28.42']
# Data written to CSV: ['2024-05-19 17:45:00', '28.799']
# Data written to CSV: ['2024-05-19 18:00:00', '28.42']
# Data written to CSV: ['2024-05-19 18:15:00', '28.647']
# Data written to CSV: ['2024-05-19 18:30:00', '28.345']
# Data written to CSV: ['2024-05-19 18:45:00', '28.799']
# Data written to CSV: ['2024-05-19 19:00:00', '28.269']
# Data written to CSV: ['2024-05-19 19:15:00', '28.119']
# Data written to CSV: ['2024-05-19 19:30:00', '28.42']
# Data written to CSV: ['2024-05-19 19:45:00', '29.104']
# Data written to CSV: ['2024-05-19 20:00:00', '28.799']
# Data written to CSV: ['2024-05-19 20:15:00', '28.951']
# Data written to CSV: ['2024-05-19 20:30:00', '28.875']
# Data written to CSV: ['2024-05-19 20:45:00', '28.647']
# Data written to CSV: ['2024-05-19 21:00:00', '28.799']
# Data written to CSV: ['2024-05-19 21:15:00', '28.875']
# Data written to CSV: ['2024-05-19 21:30:00', '28.194']
# Data written to CSV: ['2024-05-19 21:45:00', '28.799']
# Data written to CSV: ['2024-05-19 22:00:00', '28.496']
# Data written to CSV: ['2024-05-19 22:15:00', '27.893']
# Data written to CSV: ['2024-05-19 22:30:00', '28.043']
# Data written to CSV: ['2024-05-19 22:45:00', '28.345']
# Data written to CSV: ['2024-05-19 23:00:00', '28.345']
# Data written to CSV: ['2024-05-19 23:15:00', '28.119']
# Data written to CSV: ['2024-05-19 23:30:00', '28.345']
# Data written to CSV: ['2024-05-19 23:45:00', '27.744']
# Data written to CSV: ['2024-05-20 00:00:00', '28.42']
# Data written to CSV: ['2024-05-20 00:15:00', '28.496']
# Data written to CSV: ['2024-05-20 00:30:00', '28.496']
# Data written to CSV: ['2024-05-20 00:45:00', '28.043']
# Data written to CSV: ['2024-05-20 01:00:00', '28.269']
# Data written to CSV: ['2024-05-20 01:15:00', '28.345']
# Data written to CSV: ['2024-05-20 01:30:00', '28.043']
# Data written to CSV: ['2024-05-20 01:45:00', '27.445']
# Data written to CSV: ['2024-05-20 02:00:00', '28.951']
# Data written to CSV: ['2024-05-20 02:15:00', '27.968']
# Data written to CSV: ['2024-05-20 02:30:00', '28.496']
# Data written to CSV: ['2024-05-20 02:45:00', '27.968']
# Data written to CSV: ['2024-05-20 03:00:00', '27.669']
# Data written to CSV: ['2024-05-20 03:15:00', '28.119']
# Data written to CSV: ['2024-05-20 03:30:00', '28.345']
# Data written to CSV: ['2024-05-20 03:45:00', '28.119']
# Data written to CSV: ['2024-05-20 04:00:00', '27.744']
# Data written to CSV: ['2024-05-20 04:15:00', '27.968']
# Data written to CSV: ['2024-05-20 04:30:00', '28.496']
# Data written to CSV: ['2024-05-20 04:45:00', '28.043']
# Data written to CSV: ['2024-05-20 05:00:00', '28.42']
# Data written to CSV: ['2024-05-20 05:15:00', '27.445']
# Data written to CSV: ['2024-05-20 05:30:00', '28.043']
# Data written to CSV: ['2024-05-20 05:45:00', '28.043']
# Data written to CSV: ['2024-05-20 06:00:00', '28.043']
# Data written to CSV: ['2024-05-20 06:15:00', '28.043']
# Data written to CSV: ['2024-05-20 06:30:00', '27.222']
# Data written to CSV: ['2024-05-20 06:45:00', '28.345']
# Data written to CSV: ['2024-05-20 07:00:00', '27.818']
# Data written to CSV: ['2024-05-20 07:15:00', '28.496']
# Data written to CSV: ['2024-05-20 07:30:00', '27.893']
# Data written to CSV: ['2024-05-20 07:45:00', '27.818']
# Data written to CSV: ['2024-05-20 08:00:00', '28.345']
# Data written to CSV: ['2024-05-20 08:15:00', '27.893']
# Data written to CSV: ['2024-05-20 08:30:00', '28.043']
# Data written to CSV: ['2024-05-20 08:45:00', '27.669']
# Data written to CSV: ['2024-05-20 09:00:00', '28.194']
# Data written to CSV: ['2024-05-20 09:15:00', '27.594']
# Data written to CSV: ['2024-05-20 09:30:00', '27.669']
# Data written to CSV: ['2024-05-20 09:45:00', '28.42']
# Data written to CSV: ['2024-05-20 10:00:00', '27.893']
# Data written to CSV: ['2024-05-20 10:15:00', '27.893']
# Data written to CSV: ['2024-05-20 10:30:00', '27.968']
# Data written to CSV: ['2024-05-20 10:45:00', '28.194']
# Data written to CSV: ['2024-05-20 11:00:00', '28.043']
# Data written to CSV: ['2024-05-20 11:15:00', '27.968']
# Data written to CSV: ['2024-05-20 11:30:00', '28.345']
# Data written to CSV: ['2024-05-20 11:45:00', '28.269']
# Data written to CSV: ['2024-05-20 12:00:00', '27.371']
# Data written to CSV: ['2024-05-20 12:15:00', '27.893']
# Data written to CSV: ['2024-05-20 12:30:00', '27.968']
# Data written to CSV: ['2024-05-20 12:45:00', '28.043']
# Data written to CSV: ['2024-05-20 13:00:00', '27.968']
# Data written to CSV: ['2024-05-20 13:15:00', '27.893']
# Data written to CSV: ['2024-05-20 13:30:00', '27.222']
# Data written to CSV: ['2024-05-20 13:45:00', '27.445']
# Data written to CSV: ['2024-05-20 14:00:00', '27.669']
# Data written to CSV: ['2024-05-20 14:15:00', '28.194']
# Data written to CSV: ['2024-05-20 14:30:00', '27.744']
# Data written to CSV: ['2024-05-20 14:45:00', '27.445']
# Data written to CSV: ['2024-05-20 15:00:00', '27.296']
# Data written to CSV: ['2024-05-20 15:15:00', '27.669']
# Data written to CSV: ['2024-05-20 15:30:00', '27.445']
# Data written to CSV: ['2024-05-20 15:45:00', '27.0']
# Data written to CSV: ['2024-05-20 16:00:00', '27.594']
# Data written to CSV: ['2024-05-20 16:15:00', '27.371']
# Data written to CSV: ['2024-05-20 16:30:00', '27.0']
# Data written to CSV: ['2024-05-20 16:45:00', '27.222']
# Data written to CSV: ['2024-05-20 17:00:00', '28.043']
# Closing the connection.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 47
#      45 except Exception as e:
#      46     print(f"An error occurred: {e}")
# ---> 47 time.sleep(5)  # Wait for a few seconds before attempting to reconnect
#
# KeyboardInterrupt:

# %%
import requests
import pandas as pd
from pymongo import MongoClient
from io import StringIO
import io 
import time


# MongoDB setup
mongo_client = MongoClient("mongodb://localhost:27017/")
db = mongo_client["iot_database"]
collection = db["sensor_data"]

# URL endpoint for the streaming data
url = "https://www.floods.it/api/v1/monitoring/38561.csv"

def fetch_and_store_data():
    response = requests.get(url)
    if response.status_code == 200:
        # Read CSV data from the response
        data = response.content.decode('utf-8')
        df = pd.read_csv(io.StringIO(data))


        # Convert DataFrame to dictionary
        data_dict = df.to_dict("records")

        # Insert data into MongoDB
        if data_dict:
            collection.insert_many(data_dict)
            print(f"Inserted {len(data_dict)} records into MongoDB")
        else:
            print("No new data to insert")
    else:
        print(f"Failed to fetch data: {response.status_code}")

if __name__ == "__main__":
    while True:
        try:
            fetch_and_store_data()
        except Exception as e:
            print(f"An error occurred: {e}")
        # Wait for a while before fetching new data
        time.sleep(3599)  # Fetch data every 60 seconds
# Out:
# An error occurred: localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 664b7d877319863b37f419dd, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 44
#      42     print(f"An error occurred: {e}")
#      43 # Wait for a while before fetching new data
# ---> 44 time.sleep(3599)  # Fetch data every 60 seconds
#
# KeyboardInterrupt:
